# %%
print("hello world")
# Out:
# hello world

# %%
! pip install --upgrade langchain -i https://pypi.org/simple
# Out:
# ...
#      ---------------------------------------- 0.0/112.7 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/112.7 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/112.7 kB ? eta -:--:--
#      --- ------------------------------------ 10.2/112.7 kB ? eta -:--:--
#      ---------- -------------------------- 30.7/112.7 kB 131.3 kB/s eta 0:00:01
#      -------------------- ---------------- 61.4/112.7 kB 273.8 kB/s eta 0:00:01
#      -------------------- ---------------- 61.4/112.7 kB 273.8 kB/s eta 0:00:01
#      -------------------- ---------------- 61.4/112.7 kB 273.8 kB/s eta 0:00:01
#      ------------------------------------ 112.7/112.7 kB 298.8 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/173.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/173.7 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/173.7 kB ? eta -:--:--
# ...

# %%
! pip uninstall langchain-openai
# Out:
# No global/local python version has been set yet. Please set the global/local version by typing:
# pyenv global 3.7.4
# pyenv local 3.7.4

# %%
! pip install openai
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pyenv local 3.10.11

# %%
! pip install langchain-community
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
! pip show langchain-community
# Out:
# Name: langchain-community
# Version: 0.4.1
# Summary: Community contributed LangChain integrations.
# Home-page:
# Author:
# Author-email:
# License: MIT
# Location: c:\users\徐康乐\.pyenv\pyenv-win\versions\3.10.11\lib\site-packages
# Requires: aiohttp, dataclasses-json, httpx-sse, langchain-classic, langchain-core, langsmith, numpy, pydantic-settings, PyYAML, requests, SQLAlchemy, tenacity
# Required-by:

# %%
#字符模板, LLM 
from langchain.prompts import PromptTemplate

prompt = PromptTemplate.from_template("你是一个取名大师，帮我取一个具有 {country} 特色的名字")
print(prompt.format(country="法国"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 2
#       1 #字符模板, LLM
# ----> 2 from langchain.prompts import PromptTemplate
#       4 prompt = PromptTemplate.from_template("你是一个取名大师，帮我取一个具有 {country} 特色的名字")
#       5 print(prompt.format(country="法国"))
#
# ModuleNotFoundError: No module named 'langchain'

# %%
from langchain.prompts import ChatPromptTemplate

chat_template = ChatPromptTemplate.from_messages(
    [
        ("system", "你是一个取名大师，帮我取一个具有 {country} 特色的名字"),
        ("human", "{question}"),
        ('ai', "你好！我状态非常好！"),
        ("human", "{user_input}"),
    ] 
)

chat_template.format_messages(name = "程大师", country="法国", question="你叫什么名字？", user_input="你现在感觉怎么样？")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from langchain.prompts import ChatPromptTemplate
#       3 chat_template = ChatPromptTemplate.from_messages(
#       4     [
#       5         ("system", "你是一个取名大师，帮我取一个具有 {country} 特色的名字"),
#    (...)
#       9     ]
#      10 )
#      12 chat_template.format_messages(name = "程大师", country="法国", question="你叫什么名字？", user_input="你现在感觉怎么样？")
#
# ModuleNotFoundError: No module named 'langchain'

# %%
from langchain.schema import SystemMessage, HumanMessage, AIMessage

# 直接创建消息
sy = SystemMessage(content="你是一个取名大师，帮我取一个具有 {country} 特色的名字",
                   additional_kwargs={"country": "法国"})
hu = HumanMessage(content="{question}")
ai = AIMessage(content="你好！我状态非常好！")
hu2 = HumanMessage(content="{user_input}")
# 创建消息列表
[sy, hu, ai, hu2]
# Out:
# [SystemMessage(content='你是一个取名大师，帮我取一个具有 {country} 特色的名字', additional_kwargs={'country': '法国'}, response_metadata={}),
#  HumanMessage(content='{question}', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='你好！我状态非常好！', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='{user_input}', additional_kwargs={}, response_metadata={})]

# %%
from langchain.prompts import AIMessagePromptTemplate
from langchain.prompts import HumanMessagePromptTemplate
from langchain.prompts import SystemMessagePromptTemplate
from langchain.prompts import ChatMessagePromptTemplate

prompt = "愿{subject}与你同在！"
system_message_prompt = SystemMessagePromptTemplate.from_template(template=prompt)
human_message_prompt = HumanMessagePromptTemplate.from_template(template=prompt)
ai_message_prompt = AIMessagePromptTemplate.from_template(template=prompt)
chat_message_prompt = ChatMessagePromptTemplate.from_template(role='天行者',template=prompt)
print(system_message_prompt.format(subject="力量"))
print(human_message_prompt.format(subject="力量"))  
print(ai_message_prompt.format(subject="力量"))
print(chat_message_prompt.format(subject="力量"))
# Out:
# content='愿力量与你同在！' additional_kwargs={} response_metadata={}
# content='愿力量与你同在！' additional_kwargs={} response_metadata={}
# content='愿力量与你同在！' additional_kwargs={} response_metadata={}
# content='愿力量与你同在！' additional_kwargs={} response_metadata={} role='天行者'

# %%
# 自定义模板
from langchain.prompts import StringPromptTemplate

# 定义一个简单的函数作为示例效果
def hello_world():
    print("hello, world")

PROMPT = """\
    你是一个非常又经验和天赋的程序员，现在给你如下函数名称，你会按照如下格式，
    输出这段代码的名称、源代码、中文解释。
    函数名称： {function_name}
    源代码：
    {source_code}
    代码解释：
    """

import inspect

def get_source_code(function_name):
    #获得源代码
    return inspect.getsource(function_name)

#定义的模板class 
class CustmPrompt(StringPromptTemplate):

    def format(self, **kwargs) -> str:
        #获得源代码
        source_code  = get_source_code(kwargs["function_name"])

        #生成提示词模板
        prompt  =  PROMPT.format(
            function_name = kwargs["function_name"].__name__, source_code = source_code
        )

        return prompt
a = CustmPrompt(input_variables = ["function_name"])
pm = a.format(function_name = hello_world)

print(pm)

# 和LLM 连接起来 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
from langchain.chat_models import init_chat_model

# 配置 API Key 和 Base URL  https://api.openai-hk.com/v1/chat/completions
model = init_chat_model(
    model="deepseek-v3.2", 
    model_provider = "openai",
    api_key = "sk-077482897415462dba6706ad0fffd7a9",
    base_url = "https://dashscope.aliyuncs.com/compatible-mode/v1",
    )

response = model.invoke('你是谁？')
print(response)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # 自定义模板
# ----> 2 from langchain.prompts import StringPromptTemplate
#       4 # 定义一个简单的函数作为示例效果
#       5 def hello_world():
#
# ModuleNotFoundError: No module named 'langchain'
